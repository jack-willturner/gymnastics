# %% [markdown]
# # PyCLS

# %%
from gymnastics.benchmarks import get_benchmark

nds_resnet = get_benchmark("NDS_resnet", path_to_api="/Users/jackturner/work/nds/data/")
# Out:
# list indices must be integers or slices, not str

# %%
model = nds_resnet.sample_random_architecture()

model
# Out:
# AnyNet(
#   (stem): ResStemIN(
#     (conv): Conv2d(3, 12, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (s1): AnyStage(
#     (b1): ResBasicBlock(
#       (proj): Conv2d(12, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (f): BasicTransform(
#         (a): Conv2d(12, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (s2): AnyStage(
#     (b1): ResBasicBlock(
#       (proj): Conv2d(16, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (f): BasicTransform(
#         (a): Conv2d(16, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (b2): ResBasicBlock(
#       (f): BasicTransform(
#         (a): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (s3): AnyStage(
#     (b1): ResBasicBlock(
#       (proj): Conv2d(80, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (f): BasicTransform(
#         (a): Conv2d(80, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (b2): ResBasicBlock(
#       (f): BasicTransform(
#         (a): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (b3): ResBasicBlock(
#       (f): BasicTransform(
#         (a): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (b4): ResBasicBlock(
#       (f): BasicTransform(
#         (a): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (s4): AnyStage(
#     (b1): ResBasicBlock(
#       (proj): Conv2d(32, 48, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (f): BasicTransform(
#         (a): Conv2d(32, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (b2): ResBasicBlock(
#       (f): BasicTransform(
#         (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (b3): ResBasicBlock(
#       (f): BasicTransform(
#         (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (b4): ResBasicBlock(
#       (f): BasicTransform(
#         (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (b5): ResBasicBlock(
#       (f): BasicTransform(
#         (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (b6): ResBasicBlock(
#       (f): BasicTransform(
#         (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (b7): ResBasicBlock(
#       (f): BasicTransform(
#         (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (b8): ResBasicBlock(
#       (f): BasicTransform(
#         (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (a_relu): ReLU(inplace=True)
#         (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (head): AnyHead(
#     (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): ReturnFeatureLayer(
#       (mod): Linear(in_features=48, out_features=1, bias=True)
#     )
#   )
# )

# %%
for child in model.children():
    print(child)
    print()
# Out:
# ResStemIN(
#   (conv): Conv2d(3, 12, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (pool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# )
#
# AnyStage(
#   (b1): ResBasicBlock(
#     (proj): Conv2d(12, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (f): BasicTransform(
#       (a): Conv2d(12, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
# )
#
# AnyStage(
#   (b1): ResBasicBlock(
#     (proj): Conv2d(16, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (f): BasicTransform(
#       (a): Conv2d(16, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (b2): ResBasicBlock(
#     (f): BasicTransform(
#       (a): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
# )
#
# AnyStage(
#   (b1): ResBasicBlock(
#     (proj): Conv2d(80, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (f): BasicTransform(
#       (a): Conv2d(80, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (b2): ResBasicBlock(
#     (f): BasicTransform(
#       (a): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (b3): ResBasicBlock(
#     (f): BasicTransform(
#       (a): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (b4): ResBasicBlock(
#     (f): BasicTransform(
#       (a): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
# )
#
# AnyStage(
#   (b1): ResBasicBlock(
#     (proj): Conv2d(32, 48, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (f): BasicTransform(
#       (a): Conv2d(32, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (b2): ResBasicBlock(
#     (f): BasicTransform(
#       (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (b3): ResBasicBlock(
#     (f): BasicTransform(
#       (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (b4): ResBasicBlock(
#     (f): BasicTransform(
#       (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (b5): ResBasicBlock(
#     (f): BasicTransform(
#       (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (b6): ResBasicBlock(
#     (f): BasicTransform(
#       (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (b7): ResBasicBlock(
#     (f): BasicTransform(
#       (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (b8): ResBasicBlock(
#     (f): BasicTransform(
#       (a): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (a_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (a_relu): ReLU(inplace=True)
#       (b): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (b_bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (relu): ReLU(inplace=True)
#   )
# )
#
# AnyHead(
#   (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): ReturnFeatureLayer(
#     (mod): Linear(in_features=48, out_features=1, bias=True)
#   )
# )

# %%
import torch

x = torch.rand((10,3,32,32))

model(x)
# Out:
# (tensor([[-0.1049],
#          [-0.1263],
#          [-0.1861],
#          [-0.1993],
#          [-0.1053],
#          [-0.3681],
#          [-0.1296],
#          [-0.1163],
#          [-0.1573],
#          [-0.1378]], grad_fn=<AddmmBackward>),
#  tensor([[1.5642, 1.6164, 2.1597, 0.7514, 2.1304, 2.3224, 1.9009, 1.9741, 1.0896,
#           2.5989, 1.1903, 0.9745, 2.2913, 1.5868, 1.0759, 1.5502, 1.0002, 2.6608,
#           1.5048, 1.9365, 0.7931, 0.7425, 1.5275, 1.0473, 1.7263, 1.5616, 1.2918,
#           3.4852, 2.0067, 1.7838, 1.7723, 2.4996, 1.6632, 4.0054, 1.6660, 1.6433,
#           2.7849, 3.2710, 6.1601, 3.8204, 2.4392, 3.9141, 3.2930, 1.9936, 4.0609,
#           2.4925, 1.4641, 1.7018, 3.9737, 1.1634, 2.3158, 1.1786, 1.5707, 2.4297,
#           2.3514, 2.1091, 1.8274, 2.0671, 1.7061, 1.3403, 3.8290, 4.6058, 1.9524,
#           0.2852, 4.6114, 2.9846],
#          [0.7427, 0.3882, 0.7463, 1.5434, 2.1905, 0.7141, 0.9153, 2.3624, 1.9426,
#           0.8912, 1.1481, 1.9439, 0.8847, 2.2501, 1.4476, 0.9197, 1.1311, 1.4817,
#           2.2590, 0.9280, 1.5408, 0.4647, 0.6767, 1.0904, 2.8912, 0.4631, 0.2979,
#           1.7885, 2.7449, 1.6105, 1.6434, 1.0089, 1.7091, 2.0139, 1.2885, 1.8061,
#           0.7438, 1.0903, 2.1058, 1.6455, 1.2625, 2.0068, 2.2329, 1.4939, 2.6492,
#           2.5932, 1.0838, 2.0976],
#          [2.5795, 0.6481, 1.2826, 1.3118, 1.9574, 2.2602, 1.2127, 1.2304, 1.5467,
#           1.1130, 1.9963, 2.3731, 2.5523, 0.6446, 1.5043, 1.7136, 2.2983, 2.1021,
#           0.3140, 1.1438, 1.2898, 1.3010, 2.0476, 1.2676, 1.8089, 1.8586, 0.9632,
#           2.5125, 1.1014, 2.0104, 2.2390, 1.3653, 1.7042, 2.2804, 2.1651, 1.8595,
#           1.5400, 1.0380, 2.1394, 0.2770, 1.1370, 1.3483, 1.7439, 1.1319, 2.4607,
#           1.6255, 2.6876, 0.7059],
#          [0.2093, 2.1470, 2.5281, 1.8398, 1.1423, 1.6147, 1.9269, 1.8724, 2.0982,
#           1.4056, 1.7666, 2.0133, 1.1937, 1.2029, 1.4069, 1.0014, 2.7107, 2.3839,
#           2.0417, 1.3183, 0.9314, 2.3832, 0.6978, 0.6429, 1.2985, 1.7414, 0.8466,
#           2.2387, 2.2753, 1.4328, 1.9907, 2.3393, 1.1123, 2.3689, 1.3392, 0.7278,
#           1.2798, 2.6961, 2.1025, 2.4046, 1.2544, 1.0038, 1.6088, 1.6623, 1.8157,
#           1.6309, 1.9018, 1.2036],
#          [1.8919, 1.2351, 1.5715, 0.8543, 2.0416, 1.7779, 2.1381, 1.6882, 1.0894,
#           0.5369, 0.8294, 2.0732, 1.7058, 1.3399, 2.2713, 0.5915, 1.5645, 1.7712,
#           1.4728, 1.5489, 0.9171, 1.3746, 2.5936, 1.1467, 1.5718, 1.4817, 0.9912,
#           2.6463, 2.1680, 1.4593, 1.3635, 2.1079, 2.0177, 1.2428, 1.1282, 1.4134,
#           2.4723, 2.2912, 1.7428, 0.5714, 2.4173, 0.9559, 2.2884, 1.2470, 2.8734,
#           2.5804, 2.2094, 0.8919]], grad_fn=<ViewBackward>))
